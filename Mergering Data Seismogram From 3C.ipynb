# %%
# !pip install obspy

# %%
# import matplotlib.pyplot as plt
# import obspy
# import numpy as np

# st = obspy.read('C:/Users/user/Project Seismology/GB11/1_2_230414_053232.3E.mseed')
# st += obspy.read('C:/Users/user/Project Seismology/GB11/1_2_230414_054000.3E.mseed')
# st += obspy.read('C:/Users/user/Project Seismology/GB11/1_2_230414_055000.3E.mseed')
# st += obspy.read('C:/Users/user/Project Seismology/GB11/1_2_230414_060000.3E.mseed')

# st1 = obspy.read('C:/Users/user/Project Seismology/GB11/1_2_230414_053232.3N.mseed')
# st1 += obspy.read('C:/Users/user/Project Seismology/GB11/1_2_230414_054000.3N.mseed')
# st1 += obspy.read('C:/Users/user/Project Seismology/GB11/1_2_230414_055000.3N.mseed')
# st1 += obspy.read('C:/Users/user/Project Seismology/GB11/1_2_230414_060000.3N.mseed')

# st2 = obspy.read('C:/Users/user/Project Seismology/GB11/1_2_230414_053232.3Z.mseed')
# st2 += obspy.read('C:/Users/user/Project Seismology/GB11/1_2_230414_054000.3Z.mseed')
# st2 += obspy.read('C:/Users/user/Project Seismology/GB11/1_2_230414_055000.3Z.mseed')
# st2 += obspy.read('C:/Users/user/Project Seismology/GB11/1_2_230414_060000.3Z.mseed')

# st.sort(['starttime'])
# st1.sort(['starttime'])
# st2.sort(['starttime'])

# t0 = st[0].stats.starttime
# t1 = st1[0].stats.starttime
# t2 = st2[0].stats.starttime

# # Go through the stream object and plot the data with a shared x axis
# fig, axes = plt.subplots(nrows=len(st)+1, sharex=True)
# ax = None

# for (tr, ax) in zip(st, axes):
#     ax.plot(tr.times(reftime=t0), tr.data)

# # Merge the data together and plot in a similar way in the bottom Axes
# st.merge(method=1)
# axes[-1].plot(st[0].times(reftime=t0), st[0].data, 'r')
# axes[-1].set_xlabel(f'seconds relative to {t0}')
# plt.show()

# # for tr in st:
# #      if isinstance(tr.data, np.ma.MaskedArray):
# #          tr.data = tr.data.filled()  # Convert masked array to regular array

# st.write(r'C:\Users\user\Project Seismology\GB11\merged_3E.mseed', format='MSEED')

# # Go through the stream object and plot the data with a shared x axis
# fig, axes = plt.subplots(nrows=len(st1)+1, sharex=True)
# ax = None

# for (tr, ax) in zip(st1, axes):
#     ax.plot(tr.times(reftime=t1), tr.data)

# # Merge the data together and plot in a similar way in the bottom Axes
# st1.merge(method=1)
# axes[-1].plot(st1[0].times(reftime=t1), st1[0].data, 'r')
# axes[-1].set_xlabel(f'seconds relative to {t1}')
# plt.show()

# for tr1 in st1:
#      if isinstance(tr1.data, np.ma.MaskedArray):
#          tr1.data = tr1.data.filled()  # Convert masked array to regular array
        
# st1.write(r'C:\Users\user\Project Seismology\GB11\merged_3N.mseed', format='MSEED')

# # Go through the stream object and plot the data with a shared x axis
# fig, axes = plt.subplots(nrows=len(st2)+1, sharex=True)
# ax = None

# for (tr, ax) in zip(st2, axes):
#     ax.plot(tr.times(reftime=t2), tr.data)

# # Merge the data together and plot in a similar way in the bottom Axes
# st2.merge(method=1)
# axes[-1].plot(st2[0].times(reftime=t2), st2[0].data, 'r')
# axes[-1].set_xlabel(f'seconds relative to {t2}')
# plt.show()

# for tr2 in st2:
#      if isinstance(tr2.data, np.ma.MaskedArray):
#          tr2.data = tr2.data.filled()  # Convert masked array to regular array
        
# st2.write(r'C:\Users\user\Project Seismology\GB11\merged_3Z.mseed', format='MSEED')

# %%
import matplotlib.pyplot as plt
import obspy
import numpy as np


st  = obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_000000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_001000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_002000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_003000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_004000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_005000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_010000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_011000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_012000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_013000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_014000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_015000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_020000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_021000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_022000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_023000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_024000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_025000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_030000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_031000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_032000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_033000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_034000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_035000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_040000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_041000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_042000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_043000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_044000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_045000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_050000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_051000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_052000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_053000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_054000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_055000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_060000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_061000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_062000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_063000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_064000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_065000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_070000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_071000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_072000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_073000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_074000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_075000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_080000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_081000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_082000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_083000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_084000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_085000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_090000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_091000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_092000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_093000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_094000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_095000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_100000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_101000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_102000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_103000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_104000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_105000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_110000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_111000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_112000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_113000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_114000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_115000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_120000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_121000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_122000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_123000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_124000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_125000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_130000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_131000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_132000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_133000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_134000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_135000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_140000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_141000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_142000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_143000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_144000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_145000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_150000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_151000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_152000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_153000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_154000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_155000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_160000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_161000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_162000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_163000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_164000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_165000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_170000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_171000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_172000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_173000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_174000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_175000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_180000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_181000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_182000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_183000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_184000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_185000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_190000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_191000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_192000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_193000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_194000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_195000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_200000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_201000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_202000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_203000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_204000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_205000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_210000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_211000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_212000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_213000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_214000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_215000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_220000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_221000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_222000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_223000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_224000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_225000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_230000.4E.mseed')
st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_231000.4E.mseed')
# st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_232000.4E.mseed')
# st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_233000.4E.mseed')
# st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_234000.4E.mseed')
# st += obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_235000.4E.mseed')

st1 = obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_000000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_001000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_002000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_003000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_004000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_005000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_010000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_011000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_012000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_013000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_014000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_015000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_020000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_021000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_022000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_023000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_024000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_025000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_030000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_031000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_032000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_033000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_034000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_035000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_040000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_041000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_042000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_043000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_044000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_045000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_050000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_051000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_052000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_053000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_054000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_055000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_060000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_061000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_062000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_063000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_064000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_065000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_070000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_071000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_072000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_073000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_074000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_075000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_080000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_081000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_082000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_083000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_084000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_085000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_090000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_091000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_092000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_093000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_094000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_095000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_100000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_101000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_102000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_103000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_104000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_105000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_110000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_111000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_112000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_113000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_114000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_115000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_120000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_121000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_122000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_123000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_124000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_125000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_130000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_131000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_132000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_133000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_134000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_135000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_140000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_141000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_142000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_143000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_144000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_145000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_150000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_151000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_152000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_153000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_154000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_155000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_160000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_161000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_162000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_163000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_164000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_165000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_170000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_171000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_172000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_173000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_174000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_175000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_180000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_181000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_182000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_183000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_184000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_185000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_190000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_191000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_192000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_193000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_194000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_195000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_200000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_201000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_202000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_203000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_204000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_205000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_210000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_211000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_212000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_213000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_214000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_215000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_220000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_221000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_222000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_223000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_224000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_225000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_230000.4N.mseed')
st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_231000.4N.mseed')
# st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_232000.4N.mseed')
# st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_233000.4N.mseed')
# st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_234000.4N.mseed')
# st1+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_235000.4N.mseed')

st2 = obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_000000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_001000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_002000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_003000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_004000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_005000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_010000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_011000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_012000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_013000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_014000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_015000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_020000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_021000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_022000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_023000.4Z.mseed')                         
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_024000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_025000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_030000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_031000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_032000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_033000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_034000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_035000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_040000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_041000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_042000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_043000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_044000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_045000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_050000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_051000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_052000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_053000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_054000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_055000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_060000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_061000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_062000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_063000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_064000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_065000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_070000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_071000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_072000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_073000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_074000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_075000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_080000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_081000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_082000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_083000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_084000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_085000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_090000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_091000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_092000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_093000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_094000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_095000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_100000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_101000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_102000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_103000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_104000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_105000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_110000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_111000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_112000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_113000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_114000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_115000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_120000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_121000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_122000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_123000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_124000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_125000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_130000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_131000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_132000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_133000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_134000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_135000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_140000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_141000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_142000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_143000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_144000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_145000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_150000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_151000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_152000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_153000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_154000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_155000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_160000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_161000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_162000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_163000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_164000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_165000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_170000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_171000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_172000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_173000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_174000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_175000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_180000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_181000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_182000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_183000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_184000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_185000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_190000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_191000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_192000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_193000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_194000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_195000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_200000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_201000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_202000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_203000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_204000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_205000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_210000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_211000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_212000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_213000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_214000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_215000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_220000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_221000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_222000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_223000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_224000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_225000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_230000.4Z.mseed')
st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_231000.4Z.mseed')
# st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_232000.4Z.mseed')
# st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_233000.4Z.mseed')
# st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_234000.4Z.mseed')
# st2+= obspy.read(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/188/1_3_240706_235000.4Z.mseed')

st.sort(['starttime'])
st1.sort(['starttime'])
st2.sort(['starttime'])

t0 = st[0].stats.starttime
t1 = st1[0].stats.starttime
t2 = st2[0].stats.starttime

# Go through the stream object and plot the data with a shared x axis
fig, axes = plt.subplots(nrows=len(st)+1, sharex=True)
ax = None

for (tr, ax) in zip(st, axes):
    ax.plot(tr.times(reftime=t0), tr.data)

# Merge the data together and plot in a similar way in the bottom Axes
data = st.merge(method=1)
axes[-1].plot(st[0].times(reftime=t0), st[0].data, 'r')
axes[-1].set_xlabel(f'seconds relative to {t0}')
plt.show()

#st.write('C:\Users\user\Project Seismology\GB01\merged_3E.mseed', format='MSEED')

# Go through the stream object and plot the data with a shared x axis
fig, axes = plt.subplots(nrows=len(st1)+1, sharex=True)
ax = None

for (tr, ax) in zip(st1, axes):
    ax.plot(tr.times(reftime=t1), tr.data)

# Merge the data together and plot in a similar way in the bottom Axes
data1 = st1.merge(method=1)
axes[-1].plot(st1[0].times(reftime=t1), st1[0].data, 'r')
axes[-1].set_xlabel(f'seconds relative to {t1}')
plt.show()

#st1.write('C:\Users\user\Project Seismology\GB01\merged_3N.mseed', format='MSEED')

# Go through the stream object and plot the data with a shared x axis
fig, axes = plt.subplots(nrows=len(st2)+1, sharex=True)
ax = None

for (tr, ax) in zip(st2, axes):
    ax.plot(tr.times(reftime=t2), tr.data)

# Merge the data together and plot in a similar way in the bottom Axes
data2 = st2.merge(method=1)
axes[-1].plot(st2[0].times(reftime=t2), st2[0].data, 'r')
axes[-1].set_xlabel(f'seconds relative to {t2}')
plt.show()

#st2.write('C:\Users\user\Project Seismology\GB01\merged_3Z.mseed', format='MSEED')
def unmask_stream(stream):
    for tr in stream:
        if np.ma.is_masked(tr.data):
            tr.data = tr.data.filled(0)

unmask_stream(st)
unmask_stream(st1)
unmask_stream(st2)

st.write(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/merged_3E.mseed', format='MSEED')
st1.write(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/merged_3N.mseed', format='MSEED')
st2.write(r'C:/Users/user/Project Seismology/uji software LFPS/N10/060724/merged_3Z.mseed', format='MSEED')
# Out:
# C:\Users\user\anaconda3\envs\seismo\lib\site-packages\obspy\io\mseed\headers.py:805: InternalMSEEDWarning: 3_1__4N_D: Warning: Data integrity check for Steim1 failed, Last sample=-8838, Xn=-8860
#   warnings.warn(_w, InternalMSEEDWarning)

# %%
threechannelsE = obspy.read(r'C:\Users\user\Project Seismology\uji software LFPS\N10\060724\merged_3E.mseed')
threechannelsN = obspy.read(r'C:\Users\user\Project Seismology\uji software LFPS\N10\060724\merged_3N.mseed')
threechannelsZ = obspy.read(r'C:\Users\user\Project Seismology\uji software LFPS\N10\060724\merged_3Z.mseed')
#print(threechannels)

# Gabungkan semua trace dari ketiga stream menjadi satu stream
combined = threechannelsE
combined += threechannelsN
combined += threechannelsZ

# Tulis stream gabungan ke satu file MiniSEED
combined.write('C:/Users/user/Project Seismology/uji software LFPS/N10/060724/combined_3component.mseed', format='MSEED')

# Cek isi stream gabungan
print(combined)

combined.plot(size=(800, 600))
# Out:
# 3 Trace(s) in Stream:
# 3.1..4E | 2024-07-06T00:00:00.000000Z - 2024-07-06T23:15:54.830000Z | 100.0 Hz, 8375484 samples
# 3.1..4N | 2024-07-06T00:00:00.000000Z - 2024-07-06T23:15:54.830000Z | 100.0 Hz, 8375484 samples
# 3.1..4Z | 2024-07-06T00:00:00.000000Z - 2024-07-06T23:15:54.830000Z | 100.0 Hz, 8375484 samples
